# %%
import requests
import json



def get_kobo_data():
    url = "https://kf.kobotoolbox.org/api/v2/assets/aZcdmftcBtnpfW8HvV78as/data.json"
    headers = {
        "Authorization": "Token d0e1084994983390bd6f50e3ee61e9c522aee152"
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        print(f"Se obtuvieron {data['count']} registros")
        return data["results"]
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None


if __name__ == "__main__":
    resultados = get_kobo_data()
    if resultados:
        
        for registro in resultados:
            print(registro.get("group_dr3zv09/Nombre_Completo"), registro.get("group_dr3zv09/sitio"), registro.get("_geolocation"))
# Out:
# Se obtuvieron 41 registros
# Hugo Alarcon sanfelipe [21.56648245, -88.21364913]
# Hugo Alarcon sanfelipe [21.56890839, -88.21694913]
# Hugo Alarcon sanfelipe [21.57007743, -88.21063757]
# Frida Castillo coloradas [21.58950933, -88.06171981]
# Frida Castillo elcuyo [21.48520352, -87.64567253]
# Frida Castillo elcuyo [21.48521533, -87.64566827]
# Frida Castillo riolagartos [21.59265418, -88.14415061]
# Gonzalo Sanson aguabrava [22.21164498, -105.566515]
# Gonzalo Sanson pimientillo [22.05018573, -105.4554579]
# Gonzalo Sanson pimientillo [22.04937131, -105.4609687]
# Frida Castillo riolagartos [21.59266318, -88.1441577]
# Frida Castillo riolagartos [21.59772699, -88.14316349]
# Frida Castillo elcuyo [21.48661827, -87.64246053]
# Frida Castillo riolagartos [21.48662283, -87.64247136]
# Frida Castillo coloradas [21.58599705, -88.06364187]
# Frida Castillo coloradas [21.58956088, -88.06171167]
# Frida Castillo riolagartos [21.61083, -88.1505]
# ...

# %%
import requests
import json

def get_kobo_data():
    url = "https://kf.kobotoolbox.org/api/v2/assets/aMQsvne8A7orHTdj6Yfh5x/data.json"
    headers = {
        "Authorization": "Token d0e1084994983390bd6f50e3ee61e9c522aee152"
    }

    response = requests.get(url, headers=headers)

    print("Status:", response.status_code)
    # Por si hay error, mostramos la respuesta completa:
    # print("Respuesta:", response.text)

    if response.status_code == 200:
        data = response.json()
        print(f"Se obtuvieron {data['count']} registros")
        return data["results"]
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None


if __name__ == "__main__":
    resultados = get_kobo_data()
    
    if resultados:

        # ============= MOSTRAR ESTRUCTURA REAL DEL REGISTRO =============
        print("\n=== Ejemplo del JSON del primer registro ===")
        print(json.dumps(resultados[0], indent=4, ensure_ascii=False))
# Out:
# Status: 200
# Se obtuvieron 70 registros
#
# === Ejemplo del JSON del primer registro ===
# {
#     "_id": 617453023,
#     "formhub/uuid": "4a87f408e4d747cbb102df3470c9223a",
#     "start": "2025-11-28T11:29:05.855-06:00",
#     "end": "2025-11-28T11:31:12.175-06:00",
#     "group_dr3zv09/Nombre_Completo": "Gonzalo Sanson",
#     "group_dr3zv09/Fecha_y_hora_de_recolecci_n": "2025-02-19T22:06:00.000-06:00",
#     "group_dr3zv09/reserva": "reservarialagartos",
#     "group_dr3zv09/sitio": "sanfelipe",
#     "group_dr3zv09/codigo": "rbrl-kbn-01",
#     "Tipo_de_sensor": "hobo___nivel_de_agua",
#     "Tipo_de_Instalaci_n": "mantenimiento___reubicaci_n_de_sensores",
#     "group_rw9dd47/group_it8nx96/Numero_de_im_genes_almacenadas": "0",
#     "group_rw9dd47/group_it8nx96/Modo_de_operaci_n_001": "video",
#     "group_rw9dd47/group_lc8rs62/Intensidad_de_la_se_al": "na",
#     "group_rw9dd47/group_lc8rs62/Estructura_F_sica_montaje": "bueno",
# ...
